# %%
import numpy as nump
import pandas as pd
try:
    fichier='pima.csv'
    col=['NbGross','Glucos','PresArt','EpaissPli','Insuline','IMC','Pedigree','Age','Class']
    data=pd.read_csv(fichier, names=col)
    print(data)
except:
    print('Erreur de lecture')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression as LR
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report,
accuracy_score, precision_score, recall_score, f1_score
from matplotlib import pyplot as plt
#separation des données entre X et Y  
dataML=data.values

x=dataML[:,-1]
y=dataML[:,-1]

test=0.3
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=test)
model = LR(solver='newton-cg')
model.fit(x_train,y_train)

y_pred=model.predict(x_test)
#Matrice de confusion

matrice=

# %%
y_pred = model.predict(x_test)
 
# Matrice de confusion
matrice = confusion_matrix(y_test, y_pred)
rapport = classification_report(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
F1_Score = f1_score(y_test, y_pred, average='weighted')
 
print(" Matrice de confusion :\n", matrice)
print("\n Rapport de classification :\n", rapport)
print(f" Accuracy : {100*accuracy:.2f}")
print(f" Précision : {100*precision:.2f}")
print(f" Rappel : {100*recall:.2f}")
print(f" F1-Score : {100*F1_Score:.2f}")
print('')
print(f'Rapport de classification: \n--------------------\n{rapport}')
print('')

ConfusionMatrixDisplay(confusion_matrix=matrice)
confusion.plot(cmap='Blues')
plt.title('La matrice de confusion')
plt.show()
